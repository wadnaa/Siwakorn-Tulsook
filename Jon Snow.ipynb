# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # for plotting graphs
import seaborn as sns
% matplotlib inline

# %% [markdown]
# # Read CSV

# %%
csv_y_train = pd.read_csv("/Users/waddnaa/Desktop/TJ2018-AUDITION/y_train.csv")
csv_y_test_index = pd.read_csv("/Users/waddnaa/Desktop/TJ2018-AUDITION/y_test_index.csv")
csv_demo = pd.read_csv("/Users/waddnaa/Desktop/TJ2018-AUDITION/demo.csv")
csv_ard = pd.read_csv("/Users/waddnaa/Desktop/TJ2018-AUDITION/adr.csv")
csv_sa = pd.read_csv("/Users/waddnaa/Desktop/TJ2018-AUDITION/sa.csv")
csv_cc_txn = pd.read_csv("/Users/waddnaa/Desktop/TJ2018-AUDITION/cc_txn.csv")

# %%
mergeing1 = pd.merge(csv_y_train, csv_y_test_index, how='left')

# %%
mergeing2 = pd.merge(mergeing1, csv_demo, how='left')

# %%
mergeing3 = pd.merge(mergeing2,csv_ard, how='left')

# %%
mergeing4 = pd.merge(mergeing3,csv_sa, how='left')

# %%
mergeing5 = pd.merge(mergeing4,csv_cc_txn, how='left')

# %%
mergeing5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 287129 entries, 0 to 287128
# Data columns (total 19 columns):
# ip_id             287129 non-null int64
# label             287129 non-null float64
# brth_yr           287129 non-null float64
# act_strt_dt       287129 non-null object
# no_of_dpnd_chl    287129 non-null float64
# cis_income        287129 non-null float64
# crn_bal           287129 non-null float64
# gnd_cd            287129 non-null float64
# mar_st_cd         287129 non-null float64
# ctf_tp_cd         287129 non-null float64
# ocp_cd            287129 non-null int64
# prov              159200 non-null object
# dt                287129 non-null object
# channel           287129 non-null object
# tp                287129 non-null object
# amt               287129 non-null float64
# category          64499 non-null object
# card              64499 non-null object
# txn_amt           64499 non-null float64
# dtypes: float64(10), int64(2), object(7)
# ...

# %%
mergeing5
# Out:
#         ip_id  label  brth_yr act_strt_dt  no_of_dpnd_chl  cis_income  \
# 0           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 1           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 2           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 3           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 4           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 5           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 6           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 7           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 8           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 9           1    0.0   1990.0  2011-12-11             0.0     45864.0
# 10          1    0.0   1990.0  2011-12-11             0.0     45864.0
# 11          1    0.0   1990.0  2011-12-11             0.0     45864.0
# ...
